# %%
import wrangles

# %%
# Replace 'your_model_id' with a valid model id for your environment
model_id = '1eddb7e8-1b2b-4a52'

# Test input that should not match any label
result = wrangles.extract.custom('no match input', model_id, use_labels=True)
if result == '':
    print('No label matched!')
else:
    print('Matched label:', result)
# Out:
# Matched label: {}
