# %%
import wrangles
import pandas as pd

# %%
df = wrangles.recipe.run(
    """
    read:
        - train.meta_data:
            model_id: 41789e35-eada-4239
    """
)
df.columns
# Out:
# INFO:root:: Reading Wrangle metadata :: 41789e35-eada-4239
# Index(['id', 'name', 'type', 'purpose', 'status', 'path', 'batch_size', 'tags',
#        'notes', 'created_by', 'date_created', 'modified_by', 'date_modified',
#        'variant', 'settings'],
#       dtype='object')
